# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashishkumar217/Chatbot-For-FAQ/blob/main/image_captioning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
from skimage import io, transform
import cv2
from pycocotools.coco import COCO
import nltk
from tqdm.notebook import tqdm

print("✅ All libraries imported successfully!")
# Out:
# ✅ All libraries imported successfully!
